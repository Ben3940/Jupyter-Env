# %%
import pandas as pd

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("./data/Zeek_Data.csv")
df.head()
# Out:
#    resp_pkts service  orig_ip_bytes  local_resp  missed_bytes protocol  \
# 0          2     dns            186       False             0      udp
# 1          2     dns            186       False             0      udp
# 2          2     dns            186       False             0      udp
# 3          2     dns            186       False             0      udp
# 4          2     dns            186       False             0      udp
#
#    duration conn_state     dest_ip  orig_pkts  ... orig_bytes  local_orig  \
# 0   0.00228         SF  143.88.5.1          2  ...      130.0       False
# 1   0.00228         SF  143.88.5.1          2  ...      130.0       False
# 2   0.00228         SF  143.88.5.1          2  ...      130.0       False
# 3   0.00228         SF  143.88.5.1          2  ...      130.0       False
# 4   0.00228         SF  143.88.5.1          2  ...      130.0       False
#
#                    datetime  history  resp_bytes                 uid src_port  \
# ...

# %% [markdown]
# # Overview of Data

# %%
df.describe()
# Out:
#           resp_pkts  orig_ip_bytes  missed_bytes      duration     orig_pkts  \
# count  23003.000000   23003.000000       23003.0  2.233800e+04  23003.000000
# mean       0.386602     149.897970           0.0  1.057302e+00      1.971569
# std        0.819321      92.104006           0.0  3.913625e+00      0.856483
# min        0.000000       0.000000           0.0  9.536743e-07      0.000000
# 25%        0.000000     134.000000           0.0  1.502037e-05      2.000000
# 50%        0.000000     138.000000           0.0  2.098083e-05      2.000000
# 75%        0.000000     158.000000           0.0  1.958132e-03      2.000000
# max        5.000000    1439.000000           0.0  6.305099e+01     12.000000
#
#        resp_ip_bytes     dest_port    orig_bytes    resp_bytes      src_port  \
# count   23003.000000  23003.000000  22338.000000  22338.000000  23003.000000
# mean       32.735904    149.131157     95.402095     22.246933  46190.409642
# ...
